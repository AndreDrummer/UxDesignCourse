# %%
import numpy as np;
import matplotlib.pyplot as plt;

# %%
# Criando labels
labels = ["Faturamento reduzido pela metade", ""]
valores = [40, 60]

# %%
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['blue', 'grey'],explode=explode,autopct="%1.1f%%")
plt.show()

# %%
# Criando labels
labels = ["Preenche agenda de forma passiva", "Outras formas"]
valores = [50, 50]

# %%
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['blue', 'grey'],explode=explode,autopct="%1.1f%%")
plt.show()

# %%
# Criando labels
labels = ["Boca-a-boca", ""]
valores = [80, 20]

# %%
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['blue', 'grey'], explode=explode,autopct="%1.1f%%")
plt.show()

# %%
# Criando labels
labels = ["Não vai ao salão", ""]
valores = [54.7, 45.3]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['red', 'grey'], explode=explode,autopct="%1.1f%%")
circulo = plt.Circle((0,0), 0.3, color='white')
p = plt.gcf();
p.gca().add_artist(circulo)
plt.show()

# %%
# Criando labels
labels = ["Medo de contaminação", ""]
valores = [61.3, 38.7]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['red', 'grey'], explode=explode,autopct="%1.1f%%")
circulo = plt.Circle((0,0), 0.3, color='white')
p = plt.gcf();
p.gca().add_artist(circulo)
plt.show()

# %%
# Criando labels
labels = ["Aprendeu se cuidar só", ""]
valores = [79.3, 20.7]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['red', 'grey'], explode=explode,autopct="%1.1f%%")
circulo = plt.Circle((0,0), 0.3, color='white')
p = plt.gcf();
p.gca().add_artist(circulo)
plt.show()

# %%
# Criando labels
labels = ["Insegurança e receio", ""]
valores = [84, 16]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['red', 'grey'], explode=explode,autopct="%1.1f%%")
circulo = plt.Circle((0,0), 0.3, color='white')
p = plt.gcf();
p.gca().add_artist(circulo)
plt.show()

# %%
# Criando labels
labels = ["Seguir a regras de segurança", ""]
valores = [92, 8]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['red', 'grey'], explode=explode,autopct="%1.1f%%")
circulo = plt.Circle((0,0), 0.3, color='white')
p = plt.gcf();
p.gca().add_artist(circulo)
plt.show()

# %%
# Criando labels
labels = ["Também são funcionários", ""]
valores = [92, 8]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['green', 'grey'], explode=explode,autopct="%1.1f%%")
plt.show()

# %%
# Criando labels
labels = ["Utilizam tecnologia", ""]
valores = [40, 60]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['green', 'grey'], explode=explode,autopct="%1.1f%%")
plt.show()

# %%
# Criando labels
labels = ["Entram capacitados", ""]
valores = [80, 20]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['green', 'grey'], explode=explode,autopct="%1.1f%%")
plt.show()

# %%
# Criando labels
labels = ["Passaram a utilizar redes sociais", ""]
valores = [40, 60]
explode = [0,0.1]
plt.pie(valores, labels=labels, colors=['green', 'grey'], explode=explode,autopct="%1.1f%%")
plt.show()
